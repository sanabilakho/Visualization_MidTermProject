# %% [markdown]
# # Midterm Project Visualisasi Data

# %% [markdown]
# Sanabila Khoirunnisa
# 1301204097

# %% [markdown]
# Import necessary library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the data (Dataset1)

# %%
df_can1 = pd.read_csv('Dataset1.csv')

# %%
df_can1
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 6888     Zimbabwe  ZWE  2015                                          NaN
# 6889     Zimbabwe  ZWE  2016                                          NaN
# 6890     Zimbabwe  ZWE  2017                                          NaN
# 6891     Zimbabwe  ZWE  2018                                          NaN
# 6892     Zimbabwe  ZWE  2019                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# ...

# %%
df_can1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6893 entries, 0 to 6892
# Data columns (total 36 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Entity                                                                                    6893 non-null   object
#  1   Code                                                                                      6189 non-null   object
#  2   Year                                                                                      6893 non-null   int64
#  3   Number of executions (Amnesty International)                                              267 non-null    object
#  4   Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                  6840 non-null   float64
# ...

# %%
df_can1_indo = df_can1[df_can1['Entity']=='Indonesia']
df_can1_indo
# Out:
#          Entity Code  Year Number of executions (Amnesty International)  \
# 2684  Indonesia  IDN  2007                                            1
# 2685  Indonesia  IDN  2008                                           10
# 2686  Indonesia  IDN  2009                                            0
# 2687  Indonesia  IDN  2013                                            5
# 2688  Indonesia  IDN  2015                                           14
# 2689  Indonesia  IDN  2016                                            4
# 2690  Indonesia  IDN  1990                                          NaN
# 2691  Indonesia  IDN  1991                                          NaN
# 2692  Indonesia  IDN  1992                                          NaN
# 2693  Indonesia  IDN  1993                                          NaN
# 2694  Indonesia  IDN  1994                                          NaN
# 2695  Indonesia  IDN  1995                                          NaN
# ...

# %% [markdown]
# specific disease data

# %%
df_can1_meningitis = df_can1_indo[df_can1_indo["Deaths - Meningitis - Sex: Both - Age: All Ages (Number)"] != 0]
df_can1_alzheimer = df_can1_indo[df_can1_indo["Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)"] != 0]
df_can1_nutrition = df_can1_indo[df_can1_indo["Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)"] != 0]

# %% [markdown]
# Nomor 1

# %%
plt.plot(df_can1_meningitis["Year"], df_can1_meningitis["Deaths - Meningitis - Sex: Both - Age: All Ages (Number)"], label="Meningitis")
plt.plot(df_can1_alzheimer["Year"], df_can1_alzheimer["Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)"], label="Alzheimer")
plt.plot(df_can1_nutrition["Year"], df_can1_nutrition["Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)"], label="Nutritional deficiencies")

plt.title('perbandingan jumlah kematian di Indonesia akibat meningitis, alzheimer dan nutritional deficiencies')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Kematian')
plt.legend()
plt.show()

# %%
df_can1_malaria_indo = df_can1[(df_can1['Entity']=='Indonesia') & (df_can1['Deaths - Malaria - Sex: Both - Age: All Ages (Number)'] != 0)]

# %% [markdown]
# Nomor 2

# %%
plt.plot(df_can1_malaria_indo['Year'], df_can1_malaria_indo['Deaths - Malaria - Sex: Both - Age: All Ages (Number)'])

plt.title('trend kenaikan jumlah kematian di Indonesia akibat malaria')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Kematian')
plt.show()

# %% [markdown]
# nutritional deficiency data at Indonesia and India

# %%
df_can1_nutrition_indo = df_can1[(df_can1['Entity'] == 'Indonesia') & (df_can1['Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)'] !=0 )]

df_can1_nutrition_india = df_can1[(df_can1['Entity'] == 'India') & (df_can1['Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)'] !=0 )]

# %% [markdown]
# Nomor 2

# %%
plt.plot(df_can1_nutrition_indo['Year'], df_can1_nutrition_indo['Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)'], label='Indonesia')
plt.plot(df_can1_nutrition_india['Year'], df_can1_nutrition_india['Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)'], label='India')

plt.title('Perubahan Jumlah Kematian Akibat Nutritional Deficiencies di Indonesia dan India')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Kematian')
plt.legend()

# Menampilkan grafik
plt.show()

# %% [markdown]
# Nomor 3

# %%
df_can1_indo2 = df_can1[df_can1['Entity']=='Indonesia']
df_can1_indo2=df_can1_indo2.drop(['Number of executions (Amnesty International)','Entity','Code','Year'],axis = 1)

df_can1_indo2.rename(columns = {'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)':'Meningitis'}, inplace = True)
df_can1_indo2.rename(columns = {"Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)":'Alzheimer'}, inplace = True)
df_can1_indo2.rename(columns = {"Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)":'Parkinson'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)':'Nutritional deficiencies'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Malaria - Sex: Both - Age: All Ages (Number)':'Malaria'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Drowning - Sex: Both - Age: All Ages (Number)':'Drowning'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)':'Interpersonal violence'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)':'Maternal disorders'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)':'HIV/AIDS'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)':'Drug use disorders'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)':'HIV/AIDS'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)':'Tuberculosis'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Cardiovascular diseases - Sex: Both - Age: All Ages (Number)':'Cardiovascular diseases'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)':'Lower respiratory infections'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number)':'Neonatal disorders'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)':'Alcohol use disorders'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Self-harm - Sex: Both - Age: All Ages (Number)':'Self-harm'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Exposure to forces of nature - Sex: Both - Age: All Ages (Number)':'Exposure to forces of nature'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Diarrheal diseases - Sex: Both - Age: All Ages (Number)':'Diarrheal diseases'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Environmental heat and cold exposure - Sex: Both - Age: All Ages (Number)':'Environmental heat and cold exposure'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)':'Neoplasms'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Conflict and terrorism - Sex: Both - Age: All Ages (Number)':'Conflict and terrorism'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Diabetes mellitus - Sex: Both - Age: All Ages (Number)':'Diabetes mellitus'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)':'Chronic kidney disease'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Poisonings - Sex: Both - Age: All Ages (Number)':'Poisonings'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)':'Protein-energy malnutrition'}, inplace = True)
df_can1_indo2.rename(columns = {'Terrorism (deaths)':'Terrorism'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Road injuries - Sex: Both - Age: All Ages (Number)':'Road injuries'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)':'Chronic respiratory diseases'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)':'Cirrhosis and other chronic liver diseases'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)':'Digestive diseases'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)':'Fire, heat, and hot substances'}, inplace = True)
df_can1_indo2.rename(columns = {'Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)':'Acute hepatitis'}, inplace = True)

plt.figure(figsize=(24,22))
mask = np.triu(np.ones_like(df_can1_indo2.corr()))
 
# plotting a triangle correlation heatmap
dataplot = sns.heatmap(df_indo_2.corr(), mask=mask,cmap="magma")
 
# displaying heatmap
plt.show()

# %% [markdown]
# A. Tentukan variabel-variabel yang memiliki nilai korelasi paling positif, dan berikan penjelasan terkait nilai korelasi tersebut.
# --> semakin tinggi nilai dari korelasi maka akan semakin kuat hubungan antara dua variabel tersebut. nilai korelasi paling positif merupakan variabel dengan warna paling cerah, beberapa variabel yang memiliki nilai korelasi yang tinggi adalah seperti parkison dan alzheimer, drowning dan meningitis, maternal disorders dan meningitis. hal ini menunjukan jika salah satu variable meningkat, maka kemungkinan besar akan terjadi peningkatan di variable lainnya.
#
# B.  Tentukan variabel-variabel yang memiliki nilai korelasi paling negatif, dan berikan
# penjelasan terkait nilai korelasi tersebut.
# --> nilai korelasi paling negatif merupakan variabel dengan warna paling gelap, contohnya ialah acute hepatitis dan HIV/AIDS. ketika salah satu variabel menurun, maka kemungkinan besar variabel lainnya akan meningkat secara linier.

# %% [markdown]
# Read the data (Dataset2)

# %%
df_can2 = pd.read_csv('Dataset2.csv')
df_can2
# Out:
#              Area  Year    Unit      Value Flag Flag Description
# 0     Afghanistan  1961  tonnes  319000.00    A  Official figure
# 1     Afghanistan  1962  tonnes  319000.00    A  Official figure
# 2     Afghanistan  1963  tonnes  319000.00    A  Official figure
# 3     Afghanistan  1964  tonnes  380000.00    A  Official figure
# 4     Afghanistan  1965  tonnes  380000.00    A  Official figure
# ...           ...   ...     ...        ...  ...              ...
# 7319     Zimbabwe  2017  tonnes    1326.90    I    Imputed value
# 7320     Zimbabwe  2018  tonnes    1342.47    I    Imputed value
# 7321     Zimbabwe  2019  tonnes    1134.00    A  Official figure
# 7322     Zimbabwe  2020  tonnes     750.00    E  Estimated value
# 7323     Zimbabwe  2021  tonnes    2908.00    A  Official figure
#
# [7324 rows x 6 columns]

# %%
df_can2_use = df_can2[['Area','Year','Value']]

# %%
df_can2_subset = df_can2[df_can2["Area"].isin(["China", "India", "Indonesia", "Thailand"])]

# %% [markdown]
# Nomor 4

# %%
plt.bar(df_can2_subset["Area"], df_can2_subset["Value"])

plt.title("Perbandingan Jumlah Produksi Beras untuk Negara China, India, Indonesia, dan Thailand")
plt.xlabel("Negara")
plt.ylabel("Jumlah Produksi Beras")
plt.show()

# %%
matrix = df_can2_subset.corr()
print(matrix)
# Out:
#            Year     Value
# Year   1.000000  0.400326
# Value  0.400326  1.000000

# %% [markdown]
# Apakah ada hubungan korelasi jumlah produksi antar negara-negara China, India, Indonesia, dan Thailand? Berikan penjelasan
# --> tentu terdapat korelasi antara negara - negara tersebut, dapat dilihat pada hasil output diatas bahwa nilai korelasi jumlah produksi beras untuk negara china, india, indonesia, dan thailand sangat tinggi, yaitu mendekati nilai 1. ini menandakan bahwa terdapat hubungan yang kuat antara jumlah produksi beras di 4 negara tersebut, sehingga dapat disimpulkan bahwa hubungan korelasi jumlah produksi beras di antara negara - negara tersebut merupakan korelasi yang positif.

# %%
China = df_can2[df_can2["Area"] == "China"]
India = df_can2[df_can2["Area"] == "India"]
Indonesia = df_can2[df_can2["Area"] == "Indonesia"]

# %%
plt.plot(China["Year"], China["Value"], label="China")
plt.plot(India["Year"], India["Value"], label="India")
plt.plot(Indonesia["Year"], Indonesia["Value"], label="Indonesia")

plt.title("Fluktuasi Produksi Beras dari 3 Negara")
plt.xlabel("Tahun")
plt.ylabel("Jumlah Produksi (dalam ton)")
plt.legend()
plt.show()

# %%
df_can2_2021 = df_can2[df_can2["Year"] == 2021]

plt.bar(df_can2_2021["Area"], df_can2_2021["Value"])
plt.title("produksi beras terbesar pada tahun 2021")
plt.xlabel("Negara")
plt.ylabel("Jumlah Produksi (dalam ton)")
plt.show()

# %%
asia_Tenggara = ['Indonesia', 'Malaysia', 'Philippines', 'Singapore', 'Thailand', 'Vietnam', 'Brunei', 'Cambodia', 'East Timor', 'Laos', 'Myanmar']
df_can2_asia_Tenggara = df_can2[df_can2['Area'].isin(asia_Tenggara)]
df_can2_asia_Tenggara
# Out:
#           Area  Year    Unit       Value Flag Flag Description
# 1036  Cambodia  1961  tonnes   2383000.0    A  Official figure
# 1037  Cambodia  1962  tonnes   2039000.0    A  Official figure
# 1038  Cambodia  1963  tonnes   2622000.0    A  Official figure
# 1039  Cambodia  1964  tonnes   2760000.0    A  Official figure
# 1040  Cambodia  1965  tonnes   2500000.0    A  Official figure
# ...        ...   ...     ...         ...  ...              ...
# 6442  Thailand  2017  tonnes  32898903.0    A  Official figure
# 6443  Thailand  2018  tonnes  32348114.0    A  Official figure
# 6444  Thailand  2019  tonnes  28617948.0    A  Official figure
# 6445  Thailand  2020  tonnes  30231025.0    A  Official figure
# 6446  Thailand  2021  tonnes  33582000.0    A  Official figure
#
# [366 rows x 6 columns]

# %%
df_can2_asia_Tenggara = df_can2_asia_Tenggara[df_can2_asia_Tenggara['Year']==2021]
df_can2_asia_Tenggara = df_can2_asia_Tenggara[['Area','Value']]
df_can2_asia_Tenggara
# Out:
#              Area       Value
# 1096     Cambodia  11410000.0
# 3395    Indonesia  54415294.0
# 4142     Malaysia   2418148.0
# 4598      Myanmar  24910000.0
# 5273  Philippines  19960170.2
# 6446     Thailand  33582000.0

# %%
colors_list = ['red', 'yellow', 'green', 'blue', 'grey', 'brown']
explode_list = [0, 0.1, 0, 0, 0, 0]
df_can2_asia_Tenggara['Value'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,        
                            pctdistance=1.15,   
                            colors=colors_list,  
                            explode=explode_list 
                            )
plt.title('persentase jumlah produksi beras pada tahun 2021 untuk negara-negara Asia Tenggara', y=1.12)
plt.axis('equal') 

# add legend
plt.legend(labels=df_can2_asia_Tenggara['Area'], loc='upper left') 

plt.show()
